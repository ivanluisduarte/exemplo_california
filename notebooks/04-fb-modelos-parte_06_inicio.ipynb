# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3,],
    'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5, 1.0,],
    'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75, 0.9,],
}

param_grid
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': [1, 2, 3],
#  'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5, 1.0],
#  'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75, 0.9]}

# %%
grid_search = grid_search_cv_regressor(
    regressor=ElasticNet(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.562e+02, tolerance: 1.413e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.451e+01, tolerance: 1.425e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.737e+01, tolerance: 1.422e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.103e+01, tolerance: 1.441e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.502e+01, tolerance: 1.440e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.022e+01, tolerance: 1.443e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.977e+01, tolerance: 1.435e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.398e+02, tolerance: 1.772e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 0.01,
#  'regressor__reg__l1_ratio': 0.1}

# %%
grid_search.best_score_
# Out:
# np.float64(-51302.33584509287)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.602359
# robust_scaler_poly__longitude                         -0.380658
# robust_scaler_poly__population_per_household          -0.341667
# robust_scaler_poly__latitude                          -0.213156
# robust_scaler_poly__latitude^2                        -0.194374
# ...                                                         ...
# ordinal_encoder__median_income_cat                     0.092252
# robust_scaler_poly__housing_median_age longitude^2     0.107785
# robust_scaler_poly__bedrooms_per_room                  0.129573
# robust_scaler_poly__housing_median_age median_i...     0.179977
# robust_scaler_poly__median_income                      0.719466
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
#                                                     coeficiente
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household ro...         -0.0
# robust_scaler_poly__bedrooms_per_room housing_m...         -0.0
# ...                                                         ...
# robust_scaler_poly__bedrooms_per_room housing_m...          0.0
# robust_scaler_poly__bedrooms_per_room housing_m...         -0.0
# robust_scaler_poly__bedrooms_per_room housing_m...         -0.0
# robust_scaler_poly__bedrooms_per_room housing_m...          0.0
# robust_scaler_poly__total_rooms^3                           0.0
#
# [209 rows x 1 columns]

# %%
coefs[~coefs['coeficiente'].between(-0.1, 0.1)]['coeficiente'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
coefs[coefs['coeficiente'].between(-0.1, 0.1) & coefs['coeficiente'] != 0.0]
# Out:
#                                                     coeficiente
# robust_scaler_poly__bedrooms_per_room^2 median_...    -0.082342
# robust_scaler_poly__bedrooms_per_room^2 latitude      -0.075256
# robust_scaler_poly__median_income^2                   -0.068430
# robust_scaler_poly__housing_median_age latitude       -0.067164
# robust_scaler_poly__median_income population_pe...    -0.058676
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.075105
# robust_scaler_poly__housing_median_age populati...     0.084514
# robust_scaler_poly__housing_median_age                 0.087835
# robust_scaler_poly__median_income total_bedrooms       0.091392
# ordinal_encoder__median_income_cat                     0.092252
#
# [143 rows x 1 columns]

# %%
coefs[~coefs["coeficiente"].between(-0.1, 0.1)]
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.602359
# robust_scaler_poly__longitude                         -0.380658
# robust_scaler_poly__population_per_household          -0.341667
# robust_scaler_poly__latitude                          -0.213156
# robust_scaler_poly__latitude^2                        -0.194374
# robust_scaler_poly__housing_median_age populati...    -0.152396
# one_hot__ocean_proximity_NEAR BAY                     -0.138592
# robust_scaler_poly__housing_median_age latitude^2     -0.119717
# robust_scaler_poly__bedrooms_per_room^2 longitude     -0.118243
# robust_scaler_poly__bedrooms_per_room rooms_per...    -0.112895
# robust_scaler_poly__housing_median_age median_i...    -0.103794
# robust_scaler_poly__housing_median_age longitude^2     0.107785
# robust_scaler_poly__bedrooms_per_room                  0.129573
# robust_scaler_poly__housing_median_age median_i...     0.179977
# robust_scaler_poly__median_income                      0.719466

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.1, 0.1)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "LinearRegression_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.557e+01, tolerance: 1.425e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.520e+01, tolerance: 1.434e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.824e+01, tolerance: 1.451e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.008e+02, tolerance: 1.429e+00
#   model = cd_fast.enet_coordinate_descent(
# /dados/app/conda/envs/machine_learning/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.284e+01, tolerance: 1.418e+00
#   model = cd_fast.enet_coordinate_descent(
#                            model   fit_time score_time   test_r2  \
# 0                 DummyRegressor   0.006433   0.007739 -0.000081
# 1                 DummyRegressor   0.006426   0.007703 -0.000146
# 2                 DummyRegressor   0.004225   0.007202 -0.001737
# 3                 DummyRegressor   0.004973   0.007985 -0.000101
# 4                 DummyRegressor   0.010821    0.02247 -0.000114
# 5               LinearRegression   0.220922   0.021937  0.682162
# 6               LinearRegression   0.094684   0.026725   0.66999
# 7               LinearRegression   0.062725   0.020229  0.649247
# 8               LinearRegression   0.064162   0.017956  0.669873
# 9               LinearRegression   0.065088   0.039615  0.669023
# 10       LinearRegression_target   0.093307   0.019193  0.691888
# 11       LinearRegression_target   0.075769   0.030793  0.678558
# 12       LinearRegression_target   0.099951   0.018195  0.653696
# 13       LinearRegression_target   0.092519   0.023829  0.684052
# 14       LinearRegression_target   0.093803    0.02243  0.682571
# 15  LinearRegression_grid_search   22.22163   0.049187  0.735049
# 16  LinearRegression_grid_search  20.389047   0.058729  0.713639
# 17  LinearRegression_grid_search  15.969501   0.041323  0.688664
# 18  LinearRegression_grid_search  15.190972   0.060528  0.717841
# 19  LinearRegression_grid_search  13.808174   0.032932  0.715589
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.014172
# 1                 -75787.787194                    -95217.629397     0.014129
# 2                 -76753.598961                    -96253.253947     0.011427
# 3                 -76837.804811                    -95983.885799     0.012958
# 4                 -76617.245449                    -96182.764729      0.03329
# 5                 -39855.690996                    -54254.958188      0.24286
# 6                 -40272.565467                    -54695.230283     0.121408
# 7                  -42178.05929                    -56955.988706     0.082954
# 8                 -40806.492497                    -55146.318803     0.082119
# 9                 -40788.496497                     -55331.35106     0.104703
# 10                -37799.947654                    -53418.387473     0.112501
# 11                -38285.046649                     -53980.55144     0.106562
# 12                -40301.931793                    -56593.627708     0.118145
# 13                -38581.615268                     -53949.11881     0.116347
# 14                -38410.942744                    -54187.078435     0.116233
# 15                -34845.111433                    -49535.852977    22.270818
# 16                 -35644.21865                    -50949.822271    20.447776
# 17                -37598.813795                    -53660.267695    16.010824
# 18                -35932.749474                    -50982.791132      15.2515
# 19                -35953.685035                    -51291.488104    13.841106

# %%
df_resultados.groupby("model").mean()
# Out:
#                                fit_time score_time   test_r2  \
# model
# DummyRegressor                 0.006576    0.01062 -0.000436
# LinearRegression               0.101516   0.025292  0.668059
# LinearRegression_grid_search  17.515865    0.04854  0.714156
# LinearRegression_target         0.09107   0.022888  0.678153
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_grid_search                -35994.915677
# LinearRegression_target                     -38675.896821
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.017195
# LinearRegression                                -55276.769408     0.126809
# LinearRegression_grid_search                    -51284.044436    17.564405
# LinearRegression_target                         -54425.752773     0.113958

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                                fit_time score_time   test_r2  \
# model
# DummyRegressor                 0.006576    0.01062 -0.000436
# LinearRegression               0.101516   0.025292  0.668059
# LinearRegression_target         0.09107   0.022888  0.678153
# LinearRegression_grid_search  17.515865    0.04854  0.714156
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_target                     -38675.896821
# LinearRegression_grid_search                -35994.915677
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.017195
# LinearRegression                                -55276.769408     0.126809
# LinearRegression_target                         -54425.752773     0.113958
# LinearRegression_grid_search                    -51284.044436    17.564405

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
